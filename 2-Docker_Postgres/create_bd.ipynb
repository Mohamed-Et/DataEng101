# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# Create connection

# %%
engine = create_engine("postgresql+psycopg2://root:root@localhost:5432/ny_taxi")

# %% [markdown]
# Test connection

# %%
engine.connect()

# %%
with engine.begin() as conn:
    query = text("""SELECT 1 as message""")
    df_test = pd.read_sql_query(query, conn)
df_test
# Out:
#    message
# 0        1

# %% [markdown]
# Read csv

# %%
df_taxi_yellow = pd.read_csv("Taxi_data/yellow_tripdata_2019-01.csv",nrows=100)

# %%
df_taxi_yellow['tpep_pickup_datetime'] = pd.to_datetime(df_taxi_yellow['tpep_pickup_datetime'])
df_taxi_yellow['tpep_dropoff_datetime'] = pd.to_datetime(df_taxi_yellow['tpep_dropoff_datetime'])

# %%
df_taxi_yellow.to_sql(name="taxi_yellow", con=engine,index=False, if_exists="replace")
# Out:
# 100

# %%
with engine.begin() as conn:
    query = text("""SELECT * FROM taxi_yellow limit 10""")
    df_test_ingestion = pd.read_sql_query(query, conn)
df_test_ingestion
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
# 5         2  2018-11-28 16:25:49   2018-11-28 16:28:26                5
# 6         2  2018-11-28 16:29:37   2018-11-28 16:33:43                5
# 7         1  2019-01-01 00:21:28   2019-01-01 00:28:37                1
# 8         1  2019-01-01 00:32:01   2019-01-01 00:45:39                1
# 9         1  2019-01-01 00:57:32   2019-01-01 01:09:32                2
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# ...

# %%
df_test_ingestion.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge             object
# dtype: object
